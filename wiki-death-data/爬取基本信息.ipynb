# %%
import requests
from lxml import etree
import pandas as pd

# %% [markdown]
# ## 2018数据

# %%
url = "http://localhost:8080/2018%20-%20Wikipedia.html"
request_headers={
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'Cookie': 'WMF-Last-Access-Global=04-Feb-2023; GeoIP=TW:TXG:Taichung:24.14:120.68:v4; WMF-Last-Access=04-Feb-2023; enwikimwuser-sessionId=c125cdce9afcc9a3a48b; enwikiwmE-sessionTickLastTickTime=1675500914546; enwikiwmE-sessionTickTickCount=38',
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'}
 
response = requests.get(url)

html = etree.HTML(response.text)

get_result = []

year_of_death = 2018

for i in range(14,26):
    lis = html.xpath("/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[" + str(i) + "]/li")
    
    for li in lis:
        name = li.xpath("./a[2]/text()")
        if name == []:
            lis2 = li.xpath("./ul/li")
            for li2 in lis2:
                name = li2.xpath("./a[1]/text()")[0]
                link = li2.xpath("./a[1]/@href")[0]
                date_of_death = li.xpath("./a[1]/text()")[0]
                year_of_birth = li2.xpath("./a[2]/text()")[0]
                description = li2.xpath("./text()[1]")[0][1:-5]
                if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                    year_of_birth = li2.xpath("./a[3]/text()")[0]
                    a = li2.xpath("./text()[1]")[0]
                    if a[0] != ',':
                        a = li2.xpath("./text()[2]")[0][2:]
                    else:
                        a = a[2:]
                    b = li2.xpath("./a[2]/text()")[0]
                    description = a + b
                get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])
                
        else:
            name = li.xpath("./a[2]/text()")[0]
            link = li.xpath("./a[2]/@href")[0]
            date_of_death = li.xpath("./a[1]/text()")[0]
            year_of_birth = li.xpath("./a[3]/text()")[0]
            description = li.xpath("./text()[2]")[0][1:-5]
            if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                year_of_birth = li.xpath("./a[4]/text()")[0]
                a = li.xpath("./text()[1]")[0]
                if a[0] != ',':
                    a = li.xpath("./text()[2]")[0][2:]
                else:
                    a = a[2:]
                b = li.xpath("./a[3]/text()")[0]
                description = a+b
            get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])

# %% [markdown]
# ## 2019数据

# %%
url = "http://localhost:8080/2019%20-%20Wikipedia.html"
request_headers={
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'Cookie': 'WMF-Last-Access-Global=04-Feb-2023; GeoIP=TW:TXG:Taichung:24.14:120.68:v4; WMF-Last-Access=04-Feb-2023; enwikimwuser-sessionId=c125cdce9afcc9a3a48b; enwikiwmE-sessionTickLastTickTime=1675500914546; enwikiwmE-sessionTickTickCount=38',
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'}
 
response = requests.get(url)

html = etree.HTML(response.text)

year_of_death = 2019

for i in range(14,26):
    lis = html.xpath("/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[" + str(i) + "]/li")

    for li in lis:
        name = li.xpath("./a[2]/text()")
        if name == []:
            lis2 = li.xpath("./ul/li")
            for li2 in lis2:
                name = li2.xpath("./a[1]/text()")[0]
                link = li2.xpath("./a[1]/@href")[0]
                year_of_birth = li2.xpath("./a[2]/text()")[0]
                date_of_death = li.xpath("./a[1]/text()")[0]
                description = li2.xpath("./text()[1]")[0][1:-7]
                if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                    year_of_birth = li2.xpath("./a[3]/text()")[0]
                    a = li2.xpath("./text()[1]")[0]
                    if a[0] != ',':
                        a = li2.xpath("./text()[2]")[0][2:]
                    else:
                        a = a[2:]
                    b = li2.xpath("./a[2]/text()")[0]
                    description = a + b
                get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])
        else:
            name = li.xpath("./a[2]/text()")[0]
            link = li.xpath("./a[2]/@href")[0]
            year_of_birth = li.xpath("./a[3]/text()")[0]
            date_of_death = li.xpath("./a[1]/text()")[0]
            description = li.xpath("./text()[2]")[0][1:-7]
            if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                year_of_birth = li.xpath("./a[4]/text()")[0]
                a = li.xpath("./text()[1]")[0]
                if a[0] != ',':
                    a = li.xpath("./text()[2]")[0][2:]
                else:
                    a = a[2:]
                b = li.xpath("./a[3]/text()")[0]
                description = a+b
            get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])

# %% [markdown]
# ## 2020-2022

# %%
# 2020
url = "http://localhost:8080/2020%20-%20Wikipedia.html"
request_headers={
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'Cookie': 'WMF-Last-Access-Global=04-Feb-2023; GeoIP=TW:TXG:Taichung:24.14:120.68:v4; WMF-Last-Access=04-Feb-2023; enwikimwuser-sessionId=c125cdce9afcc9a3a48b; enwikiwmE-sessionTickLastTickTime=1675500914546; enwikiwmE-sessionTickTickCount=38',
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'}
 
response = requests.get(url)

html = etree.HTML(response.text)


year_of_death = 2020

for i in range(14,26):
    lis = html.xpath("/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[" + str(i) + "]/li")

    for li in lis:
        name = li.xpath("./a[2]/text()")
        if name == []:
            lis2 = li.xpath("./ul/li")
            for li2 in lis2:
                name = li2.xpath("./a[1]/text()")[0]
                link = li2.xpath("./a[1]/@href")[0]
                date_of_death = li.xpath("./a[1]/text()")[0]
                year_of_birth = li2.xpath("./a[2]/text()")[0]
                description = li2.xpath("./text()[1]")[0][1:-5]
                if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                    year_of_birth = li2.xpath("./a[3]/text()")[0]
                    a = li2.xpath("./text()[1]")[0]
                    if a[0] != ',':
                        a = li2.xpath("./text()[2]")[0][2:]
                    else:
                        a = a[2:]
                    b = li2.xpath("./a[2]/text()")[0]
                    description = a + b
                get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])
                
        else:
            name = li.xpath("./a[2]/text()")[0]
            link = li.xpath("./a[2]/@href")[0]
            date_of_death = li.xpath("./a[1]/text()")[0]
            year_of_birth = li.xpath("./a[3]/text()")[0]
            description = li.xpath("./text()[2]")[0][1:-5]
            if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                year_of_birth = li.xpath("./a[4]/text()")[0]
                a = li.xpath("./text()[1]")[0]
                if a[0] != ',':
                    a = li.xpath("./text()[2]")[0][2:]
                else:
                    a = a[2:]
                b = li.xpath("./a[3]/text()")[0]
                description = a+b
            get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])

# %%
# 2021
url = "http://localhost:8080/2021%20-%20Wikipedia.html"
request_headers={
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'Cookie': 'WMF-Last-Access-Global=04-Feb-2023; GeoIP=TW:TXG:Taichung:24.14:120.68:v4; WMF-Last-Access=04-Feb-2023; enwikimwuser-sessionId=c125cdce9afcc9a3a48b; enwikiwmE-sessionTickLastTickTime=1675500914546; enwikiwmE-sessionTickTickCount=38',
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'}
 
response = requests.get(url)

html = etree.HTML(response.text)


year_of_death = 2021

for i in range(14,26):
    lis = html.xpath("/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[" + str(i) + "]/li")

    for li in lis:
        name = li.xpath("./a[2]/text()")
        if name == []:
            lis2 = li.xpath("./ul/li")
            for li2 in lis2:
                name = li2.xpath("./a[1]/text()")[0]
                link = li2.xpath("./a[1]/@href")[0]
                date_of_death = li.xpath("./a[1]/text()")[0]
                year_of_birth = li2.xpath("./a[2]/text()")[0]
                description = li2.xpath("./text()[1]")[0][1:-5]
                if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                    year_of_birth = li2.xpath("./a[3]/text()")[0]
                    a = li2.xpath("./text()[1]")[0]
                    if a[0] != ',':
                        a = li2.xpath("./text()[2]")[0][2:]
                    else:
                        a = a[2:]
                    b = li2.xpath("./a[2]/text()")[0]
                    description = a + b
                get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])
                
        else:
            name = li.xpath("./a[2]/text()")[0]
            link = li.xpath("./a[2]/@href")[0]
            date_of_death = li.xpath("./a[1]/text()")[0]
            year_of_birth = li.xpath("./a[3]/text()")[0]
            description = li.xpath("./text()[2]")[0][1:-5]
            if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                year_of_birth = li.xpath("./a[4]/text()")[0]
                a = li.xpath("./text()[1]")[0]
                if a[0] != ',':
                    a = li.xpath("./text()[2]")[0][2:]
                else:
                    a = a[2:]
                b = li.xpath("./a[3]/text()")[0]
                description = a+b
            get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])

# %%
# 2022
url = "http://localhost:8080/2022%20-%20Wikipedia.html"
request_headers={
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'Cookie': 'WMF-Last-Access-Global=04-Feb-2023; GeoIP=TW:TXG:Taichung:24.14:120.68:v4; WMF-Last-Access=04-Feb-2023; enwikimwuser-sessionId=c125cdce9afcc9a3a48b; enwikiwmE-sessionTickLastTickTime=1675500914546; enwikiwmE-sessionTickTickCount=38',
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'}
 
response = requests.get(url)

html = etree.HTML(response.text)


year_of_death = 2022

for i in range(13,25):
    lis = html.xpath("/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[" + str(i) + "]/li")

    for li in lis:
        name = li.xpath("./a[2]/text()")
        if name == []:
            lis2 = li.xpath("./ul/li")
            for li2 in lis2:
                name = li2.xpath("./a[1]/text()")[0]
                link = li2.xpath("./a[1]/@href")[0]
                date_of_death = li.xpath("./a[1]/text()")[0]
                year_of_birth = li2.xpath("./a[2]/text()")[0]
                description = li2.xpath("./text()[1]")[0][1:-5]
                if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                    year_of_birth = li2.xpath("./a[3]/text()")[0]
                    a = li2.xpath("./text()[1]")[0]
                    if a[0] != ',':
                        a = li2.xpath("./text()[2]")[0][2:]
                    else:
                        a = a[2:]
                    b = li2.xpath("./a[2]/text()")[0]
                    description = a + b
                get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])
                
        else:
            name = li.xpath("./a[2]/text()")[0]
            link = li.xpath("./a[2]/@href")[0]
            date_of_death = li.xpath("./a[1]/text()")[0]
            year_of_birth = li.xpath("./a[3]/text()")[0]
            description = li.xpath("./text()[2]")[0][1:-5]
            if year_of_birth[0] != '1' and year_of_birth[0] != '2':
                year_of_birth = li.xpath("./a[4]/text()")[0]
                a = li.xpath("./text()[1]")[0]
                if a[0] != ',':
                    a = li.xpath("./text()[2]")[0][2:]
                else:
                    a = a[2:]
                b = li.xpath("./a[3]/text()")[0]
                description = a+b
            get_result.append([name, link, year_of_birth, year_of_death, date_of_death, description])

# %%
# 保存到csv
name = ['name','link', 'year_of_birth','year_of_death','date_of_death','description']
contents = pd.DataFrame(columns=name, data=get_result)
contents.to_csv('E:/wiki_death/data/people_data3.csv', encoding='utf-16')

# %%
print(get_result)
# Out:
# [['Thomas S. Monson', 'https://en.wikipedia.org/wiki/Thomas_S._Monson', '1927', 2018, 'January 2', ' American religious leader and writer'], ['Aharon Appelfeld', 'https://en.wikipedia.org/wiki/Aharon_Appelfeld', '1932', 2018, 'January 4', ' Ukrainian-Israeli writer'], ['Thomas Bopp', 'https://en.wikipedia.org/wiki/Thomas_Bopp', '1949', 2018, 'January 5', ' American astronomer'], ['Antonio Angelillo', 'https://en.wikipedia.org/wiki/Antonio_Valent%C3%ADn_Angelillo', '1937', 2018, 'January 5', ' Italian-Argentine footballer'], ['John Young', 'https://en.wikipedia.org/wiki/John_Young_(astronaut)', '1930', 2018, 'January 5', ' American astronaut'], ['Horace Ashenfelter', 'https://en.wikipedia.org/wiki/Horace_Ashenfelter', '1923', 2018, 'January 6', ' American Olympic athlete'], ['France Gall', 'https://en.wikipedia.org/wiki/France_Gall', '1947', 2018, 'January 7', ' French singer'], ['Peter Sutherland', 'https://en.wikipedia.org/wiki/Peter_Sutherland', '1946', 2018, 'January 7', ' Irish b
# ...

# %%
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[14]
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[15]
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[16]
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[25]
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[14]
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[25]
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[25]
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[14]
/html/body/div[1]/div/div[3]/main/div[2]/div[3]/div[1]/ul[13]
